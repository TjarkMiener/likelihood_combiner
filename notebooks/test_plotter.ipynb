# %% [markdown]
# # Test plotter
# The output of LklCom are stored in HDF5 format using pandas.

# %% [markdown]
# ### Import libraries
# First, we need to import some libraries.

# %%
# Plotting libraries
import likelihood_combiner as lklcom
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# Reading the HDF5 file with pandas
import pandas as pd

# %%
mock_file = '/Users/tmiener/deeplearning/likelihood_combiner/output/test_output_hdf5.hdf5'

fig, ax = plt.subplots()

lklcom.plotter.plot_thermal_relic(ax=ax)

lklcom.plotter.plot_sigmav_ULs_from_hdf5(file=mock_file, channel="WW", ax=ax)
lklcom.plotter.plot_sigmav_CLbands_from_hdf5(file=mock_file, channel="WW", ax=ax)

ax.set_xbound(lower=100.0,upper=100000.0)
ax.set_ybound(lower=1e-28,upper=1e-20)


plt.show()

# %%
# Out:
# reco_particle        gh_score       ...      reco_az       particle_type
#                                     ...        rad
# ------------- --------------------- ... ------------------ -------------
#             1    0.5048930048942566 ...  3.104599952697754             2
#             1    0.6881352066993713 ...  3.131497383117676             2
#             1    0.9905767440795898 ... 3.0120723247528076             2
#             1    0.8903766870498657 ...  3.114461660385132             2
#             1    0.5478326678276062 ... 3.2488040924072266             2
#             1    0.9511439204216003 ... 3.0442397594451904             2
#             1    0.9654715657234192 ...  3.043936014175415             2
#             1    0.9628927707672119 ... 3.0508015155792236             2
#             1    0.8497564792633057 ... 3.0425798892974854             2
#             0   0.46671029925346375 ...  3.061176300048828             2
# ...
